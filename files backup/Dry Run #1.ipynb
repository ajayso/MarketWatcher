# %%
from Run import Program
# Out:
# Using TensorFlow backend.
# Commencing Feature Extraction ...
#
# Final Technical Feature Set is:
#  ['DPO', 'Donchain', 'BBANDS', 'ATR', 'SAR']
# Final World Market Feature Set is:
#  ['BSE', 'DJI', 'FCHIX', 'FTSE', 'GDAXI', 'GSPC', 'PSEI', 'TWII']
# Final Commodity Market Feature Set is:
#  ['Aluminium', 'Platinum', 'Cocoa']
# Final Curency data Feature Set is:
#  ['USDINR']
#
#
# Appending Feature List into the Target data set ....
#
# 3835 common with DPO
# 3337 common with USDINR
# 733 common with Aluminium
# 655 common with Platinum
# 563 common with Cocoa
# 498 common with BSE
# 496 common with DJI
# 496 common with FCHIX
# 491 common with FTSE
# 485 common with GDAXI
# 485 common with GSPC
# 462 common with PSEI
# 439 common with TWII
#
#
# Final Data Set contains 439 rows and 20 columns
#
# The Column List is :
#
# Index(['Open', 'High', 'Low', 'Adj Close', 'Close', 'Volume',
#        'Turnover (Lacs)', 'DPO', 'Low', 'Al_Close', 'Plat_Last', 'Settle',
# ...
